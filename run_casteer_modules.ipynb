# %%
# !python3 -m generate_images_new --model="sdxl-turbo-tuned" --image_name="cowsand4" --prompt="a photo of a brown knife and a blue donut" --seed=0 --alpha="3,7,10,12" --select_best_image --num_denoising_steps=20 --save_dir="/home/toimi/00abin/CasteerPlus/casteer/assets/images"
# Out:
# /home/toimi/xtkt/lib/python3.12/site-packages/torch/amp/autocast_mode.py:270: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /home/toimi/00abin/CasteerPlus/casteer/assets/images/cowsand4
# a photo of a brown knife and a blue donut, anime style 4 5
# load checkpoint from /home/toimi/.cache/ImageReward/ImageReward.pt
# checkpoint loaded
#
# Preference predictions:
#    1.png: -2.2080
#    2.png: -2.1357
#    3.png: -2.1571
#    4.png: -2.1418
# The best image with the highest ImageReward score is /home/toimi/00abin/CasteerPlus/casteer/assets/images/cowsand4/2.png

# %%
IMAGE_NAME = '"militman2qwertfghuy"'
PROMPT = '"an assault paratrooper with a machine gun against the backdrop of a battlefield, anime style"'
save_dir = '"/content/drive/My Drive/casteer_images"'
#save_dir = save_dir.replace(' ','*')
#IMAGE_NAME

# %%
PROMPT = '"an assault paratrooper with a machine gun against the backdrop of a battlefield, anime style"'
#prompt = prompt.replace(' ','^')
PROMPT
# Out:
# '"an assault paratrooper with a machine gun against the backdrop of a battlefield, anime style"'

# %%
# !python3 -m testum --image_name={IMAGE_NAME} --save_dir={save_dir} --prompt={PROMPT} #--save_dir={save_dir}
# Out:
# militman2qwertfghuy  x  an assault paratrooper with a machine gun against the backdrop of a battlefield, anime style  x  /content/drive/My Drive/casteer_images  x  False

# %%
# !pip install clip fairscale
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 8.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for clip: filename=clip-0.2.0-py3-none-any.whl size=6989 sha256=4b360af17298dbe1ed67e80c35fdf40aedd8352223eb5edb54b278a69f78d0cc
#   Stored in directory: /root/.cache/pip/wheels/6c/fd/54/9d4e15cf829b871199a7cd3597e869a514d1624a0a43076896
# ...
#   Created wheel for fairscale: filename=fairscale-0.4.13-py3-none-any.whl size=332208 sha256=b6f2988befcf0f563a4cb587e181356b75490e796c560be9c248091803ec93e3
#   Stored in directory: /root/.cache/pip/wheels/5a/88/aa/d84b2cf1bad6b273cbf661640141a82c7b9f496e024f80aac0
# Successfully built clip fairscale
# ...

# %%
# !pip install clip
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for clip: filename=clip-0.2.0-py3-none-any.whl size=6989 sha256=a9637021d9caa4e1493091abd03f748f6c65b1544db9ac76f53de9b23046c2fc
#   Stored in directory: /root/.cache/pip/wheels/6c/fd/54/9d4e15cf829b871199a7cd3597e869a514d1624a0a43076896
# Successfully built clip
# ...
